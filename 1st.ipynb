# %%
u1=[425,78,54,["hello","There",["aman","Rohit",78],"ARE","class"],145,223,200]

# %%
u1.pop(-1)
print(u1)
# Out:
# [425, 78, 54, ['hello', 'There', ['aman', 'Rohit', 78], 'ARE', 'class'], 145, 223]

# %%
u1[3][2][2]=500
print(u1)
# Out:
# [425, 78, 54, ['hello', 'There', ['aman', 'Rohit', 500], 'ARE', 'class'], 145, 223]

# %%
print(u1[3][1:])
print(u1)
# Out:
# ['There', ['aman', 'Rohit', 500], 'ARE', 'class']
# [425, 78, 54, ['hello', 'There', ['aman', 'Rohit', 500], 'ARE', 'class'], 145, 223]

# %%
u1[3][0]=u1[3][0].replace("hello","bye")
u1[3][1]=u1[3][1].replace("There","bye")
print(u1)
# Out:
# [425, 78, 54, ['bye', 'bye', ['aman', 'Rohit', 500], 'ARE', 'class'], 145, 223]

# %%
q1 ={1,2,3,4,5,6,7,800,900,500}
q2 ={11,22,33,44,55,66,77,902,501,500}

# %%
print("{} month{} days {} hours {} min ".format(((69987//60)//24)//30,((69987//60)//24)%30,(69987//60)%24,69987%60))
# Out:
# 1 month18 days 14 hours 27 min

# %%
print("{} month{} days {} hours {} min ".format(((90760//60)//24)//30,((90760//60)//24)%30,(90760//60)%24,90760%60))
# Out:
# 2 month3 days 0 hours 40 min

# %%
q1.union(q2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 11, 22, 33, 44, 55, 66, 77, 500, 501, 800, 900, 902}

# %%
q1.remove(5)

# %%
q1
# Out:
# {1, 2, 3, 4, 6, 7, 500, 800, 900}

# %%
q1.update(q2)

# %%
d={}

# %%
type(d)
# Out:
# dict

# %%
d={"name":["A","B","C","D"],"ID":[1001,1002,1003,1004]}

# %%
d
# Out:
# {'name': ['A', 'B', 'C', 'D'], 'ID': [1001, 1002, 1003, 1004]}

# %%
d.keys()
# Out:
# dict_keys(['name', 'ID'])

# %%
d.values()
# Out:
# dict_values([['A', 'B', 'C', 'D'], [1001, 1002, 1003, 1004]])

# %%
d["name"]
# Out:
# ['A', 'B', 'C', 'D']

# %%
d["ID"]
# Out:
# [1001, 1002, 1003, 1004]

# %%
d
# Out:
# {'name': ['A', 'B', 'C', 'D'], 'ID': [1001, 1002, 1003, 1004]}

# %%
d["name"]
# Out:
# ['A', 'B', 'C', 'D']

# %%
type(d["name"])
# Out:
# list

# %%
d={"name":["A","B","C","D"],
   "ID":[1001,1002,1003,1004]}

# %%
import matplotlib.pyplot as plt 
x = [30, 50, 63] 
y = [10, 20, 30] 
plt.plot(x, y)
plt.title("Line Chart")
plt.legend(["doted"])
plt.show()

# %%
print(86**2)
# Out:
# 7396

# %%
x=input ("Enter the string ")
if x[0] == "a" and x[-1]=="r":
    print("conidtion is true")
else:
    printf("condition is false")

# %%
x="Ayushi"
if(type(x)==int or type(x)==float):
    if(x%5==0):

        print("int or float and divisible by 5")
    else:

        print("int or float and not divisible by 5")
elif(type(x)==str):

    if(x[0]=="a" or x[0]=="A"):

        print("string and first letter is a or A")

    else:

        print("string and first letter is not a or A")

else:

    print("there is no condition")
# Out:
# string and first letter is a or A

# %%
#import matplotlib.pyplot as plt 
#x = [30, 50, 63,55,4,7,4,8,6,5,2,6,6,2,5] 
#y = [10, 20, 30,47,56,3,5,2,3,6,6,4,5,2,6]
#plt.xlabel("ipl")
#plt.ylabel("t20")
#plt.plot(x, y,"go--",marker="*",linestyle="dashed",markersize=12.5)
#plt.title("Line Chart")
#plt.legend(["line"])

#for x1,y1 in zip(x,y):
    #plt.text(x1,y1,(y1,x1))
    
#plt.show()
# Out:
# C:\Users\piyus_6rpnrt6\AppData\Local\Temp\ipykernel_12440\2990946682.py:6: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "go--" (-> linestyle='--'). The keyword argument will take precedence.
#   plt.plot(x, y,"go--",marker="*",linestyle="dashed",markersize=12.5)
# C:\Users\piyus_6rpnrt6\AppData\Local\Temp\ipykernel_12440\2990946682.py:6: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "go--" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(x, y,"go--",marker="*",linestyle="dashed",markersize=12.5)

# %%
#plt.scatter(x,y)

#for x1,y1 in zip(x,y):
    #plt.text(x1,y1,(y1,x1))

# %%
import matplotlib.pyplot as plt
slices=[50,20,15,10,5]
dept=['Sales' , 'Finance', 'Production' ,'Account','HR']
cols=['magenta', 'cyan', 'green', 'red','blue']
exp=[0,0.2,0.2,0,0]
plt.pie(slices, labels=dept, colors=cols, startangle=90, explode=exp, shadow=True,autopct='%.1f%%')
plt.title("NaN")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
slices = [50, 20, 15, 10, 5]
dept = ['Sales', 'Finance', 'Production', 'Account', 'HR']
cols = ['magenta', 'cyan', 'green', 'red', 'blue'] 
exp = [0, 0, 0, 0, 0.4]
plt.pie(slices, labels=dept, colors=cols, startangle=90, explode=exp, shadow=True, autopct='%.1f%%')
plt.title("Department Distribution")  
plt.legend()
plt.show()

# %%
x="Ayushi"
if(type(x)==int or type(x)==float):
    if(x%5==0):

        print("int or float and divisible by 5")
    else:

        print("int or float and not divisible by 5")
elif(type(x)==str):

    if(x[0]=="a" or x[0]=="A"):

        print("string and first letter is a or A")

    else:

        print("string and first letter is not a or A")

else:

    print("there is no condition")
# Out:
# string and first letter is a or A

# %%
x=int(input("enter year: "))
if(x%4==0):
    print("leap year")
else:
    print("not a leap year")

# %%
s ="hello"
x = input("enter the string")
if x[0]=="f":
    d=s+" " +x
    print(d)
else:
     print(s)

# %%
name =input("enter the shape")
if name.lower() =="triangle":
    g = input("enter want you want in triangle")
    if g.lower() =="area":
        print("area of triangle is (1/2) *b *h")
    elif g.lower()=="parameter":
       print("parameter of triangle is a+b+c")

# %%
x=-110
print(abs(x))

name="rushil11"
print(len(name))

li=[100,500,50,300]
print(min(li))

y=4.89
print(round(y))

z="123appu" 
print(z.isalnum()) #it only reads alphabets and numericals

h=True
print(type(h))
# Out:
# 110
# 8
# 50
# 5
# True
# <class 'bool'>

# %%
int_a=-6
float_a=6.6
string_a="Piyush1410"
list_a=[1,2,3,4,5,6]
print(type(int_a))
print(type(float_a))
print(type(string_a))
print(type(list_a))
print("absolute value of the number:",abs(int_a))
print("length of the string:",len(string_a))
print("min value in the list:",min(list_a))
print("round off value:",round(float_a))
print("Is the string alphanumeric?",string_a.isalnum())
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'list'>
# absolute value of the number: 6
# length of the string: 10
# min value in the list: 1
# round off value: 7
# Is the string alphanumeric? True
